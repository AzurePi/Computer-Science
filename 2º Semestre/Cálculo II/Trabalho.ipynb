# %% [markdown]
# <a href="https://colab.research.google.com/github/AzurePi/Calculus/blob/main/Trabalho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # §5.1 ex 11

# %%
def f(x): return 1/(x**2 + 1)

# %% [markdown]
# ## (a)

# %%
n10 = 1/10
n30 = 1/30
n50 = 1/50

n10e = arange(0, 1, n10)
n30e = arange(0, 1, n30)
n50e = arange(0, 1, n50)

n10d = arange(0 + n10, 1 + n10, n10)
n30d = arange(0 + n30, 1 + n30, n30)
n50d = arange(0 + n50, 1 + n50, n50)

print(f"n = 10:\tSoma esquerda = {sum(f(n10e)*n10)} \tSoma direita = {sum(f(n10d)*n10)}")
print(f"n = 30:\tSoma esquerda = {sum(f(n30e)*n30)} \tSoma direita = {sum(f(n30d)*n30)}")
print(f"n = 50:\tSoma esquerda = {sum(f(n50e)*n50)} \tSoma direita = {sum(f(n50d)*n50)}")
# Out:
# n = 10:	Soma esquerda = 0.8099814972267897 	Soma direita = 0.7599814972267899
# n = 30:	Soma esquerda = 0.7936852004351657 	Soma direita = 0.7770185337684989
# n = 50:	Soma esquerda = 0.7903814967308135 	Soma direita = 0.7803814967308134

# %% [markdown]
# ## (b)

# %% [markdown]
# ### Gráficos com barras à esquerda:

# %%
print("n = 10:")
size = n10
x = arange(0, 1, size)
plt.bar(x, f(x), size, color='lightblue', align='edge', edgecolor='black')
plt.show()

print("\nn = 30:")
size = n30
x = arange(0, 1, size)
plt.bar(x, f(x), size, color='lightblue', align='edge', edgecolor='black')
plt.show()

print("\nn = 50:")
size = n50
x = arange(0, 1, size)
plt.bar(x, f(x), size, color='lightblue', align='edge', edgecolor='black')
plt.show()
# Out:
# n = 10:
# n = 30:
# n = 50:

# %% [markdown]
# ### Gráficos de barras à direita

# %%
print("n = 10:")
size = n10
x = arange(0+size, 1+size, size)
plt.bar(x, f(x), -size, color='lavender', align='edge', edgecolor='black')
plt.show()

print("\nn = 30:")
size = n30
x = arange(0+size, 1+size, size)
plt.bar(x, f(x), -size, color='lavender', align='edge', edgecolor='black')
plt.show()

print("\nn = 50:")
size = n50
x = arange(0+size, 1+size, size)
plt.bar(x, f(x), -size, color='lavender', align='edge', edgecolor='black')
plt.show()
# Out:
# n = 10:
# n = 30:
# n = 50:

# %% [markdown]
# ## (c)

# %% [markdown]
# A área exata sob f é dada pela seguinte integral:
# ![11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # §5.2 ex 13

# %%
def f(x): return x/(x+1)

# %% [markdown]
# ## n = 5

# %%
n = 2/5

ne = arange(0, 2, n)
nd = arange(0+n, 2+n, n)
nm = (ne + nd)/2

print(f"Pela regra do ponto médio, a área é {sum(f(nm)*n)}\n")

plt.bar(nm, f(nm), n, color='beige', align='center', edgecolor='black')
plt.show()
# Out:
# Pela regra do ponto médio, a área é 0.9071428571428573

# %% [markdown]
# ## n = 10

# %%
n = 2/10

ne = arange(0, 2, n)
nd = arange(0+n, 2+n, n)
nm = (ne + nd)/2

print(f"Pela regra do ponto médio, a área é {sum(f(nm)*n)}\n")

plt.bar(nm, f(nm), n, color='beige', align='center', edgecolor='black')
plt.show()
# Out:
# Pela regra do ponto médio, a área é 0.9028579059913857

# %% [markdown]
# ## n = 20

# %%
n = 2/20

ne = arange(0, 2, n)
nd = arange(0+n, 2+n, n)
nm = (ne + nd)/2

print(f"Pela regra do ponto médio, a área é {sum(f(nm)*n)}\n")

plt.bar(nm, f(nm), n, color='beige', align='center', edgecolor='black')
plt.show()
# Out:
# Pela regra do ponto médio, a área é 0.9017573653360252

# %% [markdown]
# # §11.1 ex 59

# %%
def f(x): return sqrt((3+2*x**2)/(8*x**2 + x))

x = arange(1, 20)
plt.scatter(x, f(x))
plt.show()

# %% [markdown]
# Nota-se que a sequência é convergente, e conjecturamos que seu limite é 0,5.
# Demonstramos o limite da sequência:
# ![76.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # §11.2 ex 76

# %%
from scipy import integrate

def f(x, n): return x**n

x = arange(0, 1, 1/50)

soma = 0
for n in arange(100):
    plt.plot(x, f(x, n))
    area = integrate.quad(f, 0, 1, args=(n))[0] - (integrate.quad(f, 0, 1, args=(n+1)))[0]
    soma = soma + area

plt.show()
print(f"\nA soma das áreas entre as curvas é {soma}")
# Out:
# A soma das áreas entre as curvas é 0.9900990099009896

# %% [markdown]
# Se n tender ao infinito, a soma das áreas será 1.

# %% [markdown]
# # §11.5 ex 23

# %%
def f(x): return ((-1)**(x+1))/(x**6)

# implementação das somas parciais de uma série
soma = 0
for n in arange(1, 100):
  soma = soma + f(n)
  print(f"S({n}) = {soma}")
# Out:
# S(1) = 1.0
# S(2) = 0.984375
# S(3) = 0.9857467421124828
# S(4) = 0.9855026014874828
# S(5) = 0.9855666014874828
# S(6) = 0.9855451680169752
# S(7) = 0.9855536678767275
# S(8) = 0.9855498531794619
# S(9) = 0.985551734855885
# S(10) = 0.985550734855885
# S(11) = 0.985551299329815
# S(12) = 0.9855509644318383
# S(13) = 0.9855511716080494
# S(14) = 0.9855510387977408
# S(15) = 0.9855511265892359
# S(16) = 0.9855510669845912
# S(17) = 0.985551108413784
# S(18) = 0.9855510790125899
# S(19) = 0.9855511002684358
# S(20) = 0.9855510846434359
# S(21) = 0.9855510963030515
# S(22) = 0.9855510874831463
# S(23) = 0.985551094238265
# S(24) = 0.9855510890054842
# S(25) = 0.9855510931014841
# S(26) = 0.9855510898643558
# S(27) = 0.9855510924455306
# S(28) = 0.9855510903703696
# S(29) = 0.985551092051541
# S(30) = 0.9855510906797988
# S(31) = 0.9855510918065548
# S(32) = 0.9855510908752322
# S(33) = 0.9855510916495448
# S(34) = 0.9855510910022136
# S(35) = 0.9855510915462047
# S(36) = 0.985551091086811
# S(37) = 0.9855510914765642
# S(38) = 0.9855510911444416
# S(39) = 0.985551091428634
# S(40) = 0.9855510911844934
# S(41) = 0.9855510913950151
# S(42) = 0.9855510912128336
# S(43) = 0.9855510913710273
# S(44) = 0.9855510912332163
# S(45) = 0.9855510913536436
# S(46) = 0.9855510912480949
# S(47) = 0.985551091340866
# S(48) = 0.9855510912591039
# S(49) = 0.9855510913313515
# S(50) = 0.9855510912673515
# S(51) = 0.9855510913241817
# S(52) = 0.9855510912736016
# S(53) = 0.9855510913187191
# S(54) = 0.9855510912783882
# S(55) = 0.9855510913145146
# S(56) = 0.9855510912820902
# S(57) = 0.9855510913112477
# S(58) = 0.9855510912849794
# S(59) = 0.985551091308687
# S(60) = 0.9855510912872535
# S(61) = 0.9855510913066633
# S(62) = 0.9855510912890577
# S(63) = 0.9855510913050517
# S(64) = 0.9855510912904998
# S(65) = 0.9855510913037591
# S(66) = 0.9855510912916604
# S(67) = 0.9855510913027152
# S(68) = 0.9855510912926007
# S(69) = 0.9855510913018669
# S(70) = 0.985551091293367
# S(71) = 0.9855510913011735
# S(72) = 0.9855510912939954
# S(73) = 0.9855510913006034
# S(74) = 0.9855510912945135
# S(75) = 0.9855510913001321
# S(76) = 0.9855510912949427
# S(77) = 0.9855510912997406
# S(78) = 0.9855510912953
# S(79) = 0.9855510912994138
# S(80) = 0.985551091295599
# S(81) = 0.9855510912991398
# S(82) = 0.9855510912958504
# S(83) = 0.985551091298909
# S(84) = 0.9855510912960624
# S(85) = 0.9855510912987139
# S(86) = 0.9855510912962421
# S(87) = 0.9855510912985482
# S(88) = 0.985551091296395
# S(89) = 0.9855510912984071
# S(90) = 0.9855510912965254
# S(91) = 0.9855510912982863
# S(92) = 0.9855510912966371
# S(93) = 0.9855510912981827
# S(94) = 0.9855510912967332
# S(95) = 0.9855510912980936
# S(96) = 0.9855510912968161
# S(97) = 0.9855510912980165
# S(98) = 0.9855510912968877
# S(99) = 0.9855510912979498

# %% [markdown]
# É possível perceber que, conforme n tende ao infinito, o valor da soma parcial da série tende a um valor específico (0,985551091...). Com isso, conclui-se que a série é convergente.

# %% [markdown]
# # §11.11 ex 1

# %% [markdown]
# Séries de Taylor centradas em a= 0 para *f(x) = cos x* até o grau 6:

# %% [markdown]
# ![11(1).jpg](data:image/jpeg;base64,...)

# %%
import numpy as np

def f(x, n):
  res = 0
  for i in range(n):
    #desconsidera quando n é ímpar
    if (i % 2) == 0:
      coef = (-1)**(i/2) #alterna o sinal para cada n par
      denominador = math.factorial(i)
      numerador = x**i
      res += coef * (numerador/denominador)
  return res

x = arange(-2*pi, 2*pi, 0.1)
cossenos = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, cossenos, color='red', linewidth=2.0)

for i in range(1, 8):
  cos = [f(ang, i) for ang in x]
  plt.plot(x, cos)

leg = ['f(x)']
for i in range(1,8):
    leg.append(f'T{i - 1}')
ax.legend(leg, loc=3)

ax.set_ylim([-2*pi, 4])
plt.show()

# %%
x = [pi/4, pi/2, pi]

for n in arange(1, 8):
  for i in arange(3):
    print(f"T{n-1}({x[i]}) = {f(x[i], n)}")
  print("\n")

for i in arange(3):
    print(f"f({x[i]}) = {np.cos(x[i])}")
# Out:
# T0(0.7853981633974483) = 1.0
# T0(1.5707963267948966) = 1.0
# T0(3.141592653589793) = 1.0
#
#
# T1(0.7853981633974483) = 1.0
# T1(1.5707963267948966) = 1.0
# T1(3.141592653589793) = 1.0
#
#
# T2(0.7853981633974483) = 0.6915748624659576
# T2(1.5707963267948966) = -0.23370055013616975
# T2(3.141592653589793) = -3.934802200544679
#
#
# T3(0.7853981633974483) = 0.6915748624659576
# T3(1.5707963267948966) = -0.23370055013616975
# T3(3.141592653589793) = -3.934802200544679
#
#
# T4(0.7853981633974483) = 0.707429206709773
# T4(1.5707963267948966) = 0.019968957764878226
# T4(3.141592653589793) = 0.1239099258720886
#
#
# T5(0.7853981633974483) = 0.707429206709773
# T5(1.5707963267948966) = 0.019968957764878226
# T5(3.141592653589793) = 0.1239099258720886
#
#
# T6(0.7853981633974483) = 0.7071032148228457
# T6(1.5707963267948966) = -0.0008945229984747317
# T6(3.141592653589793) = -1.2113528429825007
#
#
# f(0.7853981633974483) = 0.7071067811865476
# f(1.5707963267948966) = 6.123233995736766e-17
# f(3.141592653589793) = -1.0

# %% [markdown]
# Analisando o gráfico gerado, é possível perceber que as curvas determinadas pelos polinômios de Taylor começam a se aproximar da curva da função *f(x) = cos x*.
#
# Além disso, uma análise dos resultados de *f(x)* e de seus polinômios de Taylor para *x = π/4*, *π/2* e *π* revela que quanto maior o grau do polinômio de Taylor, mais próximo ele está de *f(x)*.
